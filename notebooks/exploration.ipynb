# %% [markdown]
# # Training the Model

# %%
from tqdm import tqdm
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
# from src.dataset import Word2VecDataset
from torch.autograd import Variable

# %%
DATA_DIR = "data/wikiTest"

# %%
cbow_dataset = Word2VecDataset( DATA_DIR, 2, "cbow")
sgram_dataset = Word2VecDataset( DATA_DIR, 2, "skipgram")
# Out:
# == Loading Data ===
# Added contents of data/wikiTest/article1.txt to corpus
# 100%|█████████████████████████████████████████| 80/80 [00:00<00:00, 5671.71it/s]
# lemmatizing and removing stopwords...
# 100%|██████████████████████████████████████| 303/303 [00:00<00:00, 17029.45it/s]
# == Loading Data ===
# Added contents of data/wikiTest/article1.txt to corpus
# 100%|████████████████████████████████████████| 80/80 [00:00<00:00, 11905.07it/s]
# lemmatizing and removing stopwords...
# 100%|██████████████████████████████████████| 303/303 [00:00<00:00, 20668.99it/s]

# %%
print(f"CBOW Vocab size - {len(cbow_dataset.vocab)},\nSkipgram Vocab size - {len(sgram_dataset.vocab)}")
# Out:
# CBOW Vocab size - 1642,
# Skipgram Vocab size - 1642

# %% [markdown]
# **Accessing elements of Dataset**

# %%
# cbow
print("CBOW ", cbow_dataset[0])

# skipgram
print("Skipgram ", sgram_dataset[0])
# Out:
# CBOW  (tensor([1, 2, 5, 6]), tensor(3))
# Skipgram  (tensor(2), tensor(3))

# %%
print("CBOW word pairs - ", len(cbow_dataset))
# Out:
# CBOW word pairs -  1797

# %%
print("Skipgram word pairs - ", len(sgram_dataset))
# Out:
# Skipgram word pairs -  7970

# %% [markdown]
# ## Model Building

# %%
#cbow model
train_loader = DataLoader(cbow_dataset, batch_size = 32, shuffle = not True)

vocab_size = len(cbow_dataset.vocab)
embedding_size = 10
embeddings_input = nn.Embedding(vocab_size, embedding_size) # embedding layer
linear = nn.Linear(embedding_size, vocab_size) # linear layer


for context, target in train_loader:
    embed = embeddings_input(context)
    out = torch.sum(linear(embed), dim = 1)
    print(out.size())
    break
# Out:
# torch.Size([32, 1642])

# %%
#skipgram model
train_loader = DataLoader(sgram_dataset, batch_size = 32, shuffle = not True)

vocab_size = len(sgram_dataset.vocab)
embedding_size = 10
embeddings_input = nn.Embedding(vocab_size, embedding_size) # embedding layer
linear = nn.Linear(embedding_size, vocab_size) # linear layer

for context, target in train_loader:
    embed = embeddings_input(context)
    out = linear(embed)
    print(out.size())
    break
# Out:
# torch.Size([32, 1642])

# %% [markdown]
# ---

# %%
MODEL_DIR = "../model"

# %%
saved_model = torch.load(f"{MODEL_DIR}/model_glove_neg10.pth")

# %%
glove_model = torch.
# Out:
# {'model_state_dict': OrderedDict([('_focal_embeddings.weight',
#                tensor([[ 0.9362,  0.2351,  0.4671,  ..., -0.7640, -0.5844,  0.3263],
#                        [-1.2083, -0.1838,  0.6645,  ...,  0.0386,  0.4747, -1.8250],
#                        [ 1.2263,  1.6646,  1.6518,  ...,  0.4046, -0.5968,  0.2918],
#                        ...,
#                        [-0.7047,  0.9246, -0.5855,  ..., -0.9109,  0.4876, -0.1069],
#                        [ 0.3169, -0.8631, -0.0330,  ...,  0.5430,  0.0518, -0.5775],
#                        [-0.5016,  0.2833,  0.3451,  ...,  1.8717, -2.0402,  0.7413]],
#                       device='cuda:0')),
#               ('_context_embeddings.weight',
#                tensor([[-1.1331,  1.3374,  1.2159,  ...,  0.2099,  0.8879, -0.5372],
#                        [ 0.4775, -0.3400, -0.5634,  ..., -0.4830, -0.6062,  0.0761],
#                        [ 0.5611,  0.1507, -0.5462,  ..., -0.4529, -1.6863, -1.3211],
#                        ...,
#                        [-1.2737, -0.0252,  0.5735,  ..., -0.1333,  0.5299, -1.0165],
#                        [ 0.9495, -0.1038, -0.5665,  ...,  0.2716,  0.3846,  0.7400],
#                        [-0.7784,  0.2069,  0.2659,  ..., -1.3034,  0.8291, -2.1918]],
#                       device='cuda:0')),
#               ('_focal_biases.weight',
#                tensor([[ 0.6453],
#                        [-0.5050],
#                        [-1.5268],
#                        ...,
#                        [ 0.8961],
#                        [-0.8335],
#                        [-0.7251]], device='cuda:0', dtype=torch.float64)),
#               ('_context_biases.weight',
#                tensor([[-0.3189],
#                        [-0.3613],
#                        [-1.3254],
#                        ...,
#                        [-1.7150],
#                        [ 0.5588],
#                        [-0.6335]], device='cuda:0', dtype=torch.float64))]),
#  'losses': [],
#  'word_to_ix': {'accessiblecomputing': 0,
#   'anarchism': 1,
#   'political': 2,
#   'philosophy': 3,
#   'movement': 4,
#   'skeptical': 5,
#   'justifications': 6,
#   'authority': 7,
#   'seek': 8,
#   'abolish': 9,
#   'institutions': 10,
#   'claim': 11,
#   'maintain': 12,
#   'unnecessary': 13,
#   'coercion': 14,
#   'hierarchy': 15,
#   'typically': 16,
#   'include': 17,
#   'though': 18,
#   'necessarily': 19,
#   'limit': 20,
#   'state': 21,
#   'capitalism': 22,
#   'advocate': 23,
#   'replacement': 24,
#   'stateless': 25,
#   'societies': 26,
#   'form': 27,
#   'free': 28,
#   'associations': 29,
#   'as': 30,
#   'historically': 31,
#   'left-wing': 32,
#   'usually': 38,
#   'place': 34,
#   'farthest': 35,
#   'leave': 36,
#   'spectrum': 37,
#   'describe': 38,
#   'alongside': 39,
#   'communalism': 40,
#   'libertarian': 44,
#   'marxism': 42,
#   'wing': 43,
#   'socialism': 44,
#   'socialist': 45,
#   'humans': 46,
#   'live': 47,
#   'without': 48,
#   'formal': 53,
#   'hierarchies': 50,
#   'long': 51,
#   'establishment': 52,
#   'realms': 53,
#   'empires': 54,
#   'with': 55,
#   'rise': 63,
#   'organise': 57,
#   'hierarchical': 58,
#   'body': 59,
#   'scepticism': 60,
#   'toward': 61,
#   'also': 62,
#   'although': 63,
#   'trace': 64,
#   'anarchist': 65,
#   'think': 66,
#   'find': 67,
#   'throughout': 68,
#   'history': 69,
#   'modern': 70,
#   'emerge': 71,
#   'enlightenment': 72,
#   'during': 73,
#   'latter': 74,
#   'half': 75,
#   '19th': 76,
#   'first': 77,
#   'decades': 78,
#   '20th': 79,
#   'century': 80,
#   'flourish': 81,
#   'part': 82,
#   'world': 83,
#   'significant': 84,
#   'role': 85,
#   'workers': 86,
#   'struggle': 87,
#   'emancipation': 88,
#   'various': 89,
#   'school': 90,
#   'period': 91,
#   'anarchists': 92,
#   'take': 93,
#   'several': 94,
#   'revolutions': 95,
#   'notably': 96,
#   'paris': 97,
#   'commune': 98,
#   'russian': 99,
#   'civil': 103,
#   'war': 103,
#   'spanish': 102,
#   'whose': 103,
#   'end': 106,
#   'mark': 105,
#   'classical': 106,
#   'era': 107,
#   'in': 108,
#   'last': 109,
#   '21st': 110,
#   'resurgent': 111,
#   'employ': 112,
#   'diversity': 113,
#   'tactics': 122,
#   'order': 115,
#   'meet': 116,
#   'ideal': 117,
#   'broadly': 118,
#   'separate': 119,
#   'revolutionary': 120,
#   'evolutionary': 121,
#   'overlap': 122,
#   'two': 123,
#   'merely': 124,
#   'descriptive': 125,
#   'aim': 131,
#   'bring': 127,
#   'violent': 128,
#   'turn': 129,
#   'past': 130,
#   'prefigure': 131,
#   'society': 132,
#   'would': 133,
#   'like': 134,
#   'criticism': 135,
#   'praxis': 136,
#   'play': 137,
#   'diverse': 138,
#   'areas': 139,
#   'human': 140,
#   'etymology': 141,
#   'terminology': 142,
#   'definition': 143,
#   'the': 144,
#   'etymological': 145,
#   'origin': 146,
#   'ancient': 147,
#   'greek': 148,
#   'anarkhia': 149,
#   'mean': 150,
#   'ruler': 158,
#   'compose': 152,
#   'prefix': 153,
#   'an-': 154,
#   'word': 155,
#   'arkhos': 156,
#   'leader': 157,
#   'suffix': 158,
#   '-ism': 159,
#   'denote': 160,
#   'ideological': 161,
#   'current': 162,
#   'favour': 163,
#   'anarchy': 164,
#   'appear': 165,
#   'english': 171,
#   '1642': 167,
#   'anarchisme': 168,
#   '1539': 169,
#   'early': 170,
#   'usages': 171,
#   'emphasise': 172,
#   'sense': 173,
#   'disorder': 174,
#   'factions': 175,
#   'within': 176,
#   'french': 177,
#   'revolution': 178,
#   'label': 179,
#   'opponents': 180,
#   'accuse': 181,
#   'share': 182,
#   'many': 183,
#   'view': 184,
#   'later': 185,
#   'revolutionaries': 186,
#   'william': 187,
#   'godwin': 188,
#   '1756–1836': 189,
#   'wilhelm': 190,
#   'weitling': 191,
#   '1808–1871': 192,
#   'contribute': 193,
#   'doctrines': 194,
#   'next': 195,
#   'generation': 196,
#   'use': 197,
#   'beliefs': 198,
#   'philosopher': 199,
#   'call': 200,
#   'pierre-joseph': 201,
#   'proudhon': 202,
#   '1809–1865': 203,
#   'birth': 204,
#   'mid-19th': 205,
#   'since': 206,
#   '1890s': 207,
#   'begin': 208,
#   'france': 209,
#   'libertarianism': 210,
#   'often': 211,
#   'synonym': 213,
#   'still': 213,
#   'common': 214,
#   'outside': 215,
#   'unite': 216,
#   'some': 217,
#   'refer': 218,
#   'individualistic': 219,
#   'free-market': 221,
#   'particular': 221,
#   'term': 222,
#   'while': 223,
#   'largely': 224,
#   'synonymous': 225,
#   'recently': 226,
#   'dilute': 227,
#   'wider': 228,
#   'adoption': 229,
#   'ideologically': 230,
#   'disparate': 231,
#   'group': 232,
#   'new': 233,
#   'marxists': 234,
#   'associate': 235,
#   'authoritarian': 236,
#   'socialists': 237,
#   'vanguard': 238,
#   'party': 239,
#   'extreme': 240,
#   'cultural': 241,
#   'liberals': 242,
#   'primarily': 243,
#   'concern': 244,
#   'liberties': 245,
#   'additionally': 246,
#   'avoid': 247,
#   "'s": 248,
#   'negative': 249,
#   'connotations': 250,
#   'connections': 251,
#   'anti-authoritarian': 252,
#   'contrast': 253,
#   'state-oriented': 254,
#   'scholars': 255,
#   'generally': 256,
#   'highlight': 257,
#   'credentials': 258,
#   'criticise': 259,
#   'attempt': 260,
#   'create': 261,
#   'dichotomies': 262,
#   'influence': 263,
#   'liberalism': 264,
#   'reject': 265,
#   'anarcho-capitalism': 266,
#   'misunderstand': 267,
#   'principles': 268,
#   'opposition': 269,
#   'central': 270,
#   'define': 271,
#   'easy': 272,
#   'task': 273,
#   'lot': 274,
#   'discussion': 275,
#   'among': 276,
#   'matter': 277,
#   'currents': 278,
#   'perceive': 279,
#   'slightly': 280,
#   'differently': 281,
#   'major': 282,
#   'definitional': 283,
#   'elements': 284,
#   'non-coercive': 293,
#   'rejection': 286,
#   'apparatus': 287,
#   'belief': 288,
#   'nature': 289,
#   'allow': 290,
#   'exist': 291,
#   'progress': 292,
#   'suggestion': 293,
#   'act': 294,
#   'pursue': 295,
#   'pre-modern': 296,
#   'before': 297,
#   'towns': 298,
#   'cities': 299,
#   'establish': 300,
#   'it': 301,
#   'creation': 302,
#   'anarchistic': 303,
#   'ideas': 304,
#   'espouse': 305,
#   'reaction': 306,
#   'notable': 307,
#   'precursors': 308,
#   'china': 309,
#   'greece': 310,
#   'philosophical': 311,
#   'legitimacy': 312,
#   'delineate': 313,
#   'taoist': 314,
#   'philosophers': 315,
#   'zhuang': 316,
#   'zhou': 317,
#   'laozi': 318,
#   'stoicism': 319,
#   'taoism': 320,
#   'say': 321,
#   'anticipations': 322,
#   'anarchic': 323,
#   'attitudes': 324,
#   'articulate': 325,
#   'tragedians': 326,
#   'aeschylus': 327,
#   'sophocles': 328,
#   'myth': 329,
#   'antigone': 330,
#   'illustrate': 331,
#   'conflict': 332,
#   'rule': 333,
#   'set': 334,
#   'personal': 335,
#   'autonomy': 336,
#   'socrates': 337,
#   'question': 338,
#   'athenian': 339,
#   'authorities': 340,
#   'constantly': 341,
#   'insist': 342,
#   'right': 343,
#   'individual': 344,
#   'freedom': 345,
#   'conscience': 346,
#   'cynics': 347,
#   'dismiss': 348,
#   'law': 349,
#   'nomos': 350,
#   'try': 351,
#   'accord': 352,
#   'physis': 353,
#   'stoics': 354,
#   'supportive': 355,
#   'base': 356,
#   'unofficial': 357,
#   'friendly': 358,
#   'relations': 359,
#   'citizens': 360,
#   'presence': 361,
#   'medieval': 362,
#   'europe': 363,
#   'activity': 364,
#   'except': 365,
#   'ascetic': 366,
#   'religious': 367,
#   'movements': 368,
#   'these': 369,
#   'muslim': 370,
#   'give': 371,
#   'sasanian': 372,
#   'empire': 373,
#   'mazdak': 374,
#   'egalitarian': 375,
#   'abolition': 376,
#   'monarchy': 377,
#   'soon': 378,
#   'execute': 379,
#   'emperor': 380,
#   'kavad': 381,
#   'i': 382,
#   'basra': 383,
#   'sects': 384,
#   'preach': 385,
#   'develop': 386,
#   'anti-state': 387,
#   'tendencies': 388,
#   'renew': 389,
#   'interest': 390,
#   'antiquity': 391,
#   'renaissance': 392,
#   'private': 393,
#   'judgment': 394,
#   'reformation': 395,
#   'restore': 396,
#   'secularism': 397,
#   'particularly': 398,
#   'challenge': 399,
#   'intellectual': 400,
#   'secular': 401,
#   '1790s': 402,
#   '1848': 403,
#   'spur': 404,
#   'development': 405,
#   'become': 406,
#   'partisan': 407,
#   'enragés': 408,
#   'saw': 409,
#   'point': 410,
#   'fermentation': 411,
#   'federalist': 412,
#   'sentiments': 413,
#   '18th': 414,
#   'england': 415,
#   'morally': 416,
#   'delegitimising': 417,
#   'max': 418,
#   'stirner': 419,
#   'pave': 420,
#   'way': 421,
#   'individualism': 422,
#   'theory': 423,
#   'mutualism': 424,
#   'fertile': 425,
#   'soil': 426,
#   'by': 427,
#   'late': 428,
#   '1870s': 429,
#   'well-defined': 430,
#   'wave': 431,
#   'unprecedented': 432,
#   'globalisation': 433,
#   'occur': 434,
#   '1880': 435,
#   '1914': 436,
#   'this': 437,
#   'consider': 438,
#   'golden': 439,
#   'age': 440,
#   'draw': 441,
#   'mikhail': 442,
#   'bakunin': 443,
#   'found': 444,
#   'collectivist': 445,
#   'enter': 446,
#   'international': 454,
#   'workingmen': 448,
#   'association': 449,
#   'class': 450,
#   'worker': 451,
#   'union': 452,
#   'know': 453,
#   '1864': 454,
#   'force': 455,
#   'karl': 456,
#   'marx': 457,
#   'lead': 458,
#   'figure': 459,
#   'member': 460,
#   'general': 461,
#   'council': 462,
#   'faction': 463,
#   'jura': 464,
#   'federation': 465,
#   'followers': 466,
#   'mutualists': 467,
#   'oppose': 468,
#   'abstentionism': 469,
#   'small': 470,
#   'property': 471,
#   'hold': 472,
#   'after': 473,
#   'bitter': 474,
#   'dispute': 475,
#   'bakuninists': 476,
#   'expel': 477,
#   '1872': 478,
#   'hague': 479,
#   'congress': 480,
#   'treat': 481,
#   'similarly': 482,
#   'second': 483,
#   'ultimately': 484,
#   '1896': 485,
#   'famously': 486,
#   'predict': 487,
#   'gain': 488,
#   'power': 489,
#   'tyrants': 490,
#   'response': 491,
#   'expulsion': 492,
#   'st.': 493,
#   'imier': 494,
#   'under': 495,
#   'peter': 496,
#   'kropotkin': 497,
#   'scientist': 498,
#   'anarcho-communism': 499,
#   'collectivism': 500,
#   'anarcho-communists': 501,
#   'inspiration': 502,
#   '1871': 503,
#   'distribution': 504,
#   'goods': 505,
#   'one': 506,
#   'need': 507,
#   'at': 508,
#   'spread': 509,
#   'feature': 510,
#   'syndicalism': 511,
#   'students': 512,
#   'import': 513,
#   'humanistic': 514,
#   'pro-science': 515,
#   'version': 516,
#   'tokyo': 517,
#   'hotspot': 518,
#   'rebellious': 519,
#   'youth': 520,
#   'countries': 521,
#   'far': 522,
#   'east': 523,
#   'travel': 524,
#   'japanese': 525,
#   'capital': 526,
#   'study': 527,
#   'latin': 528,
#   'america': 529,
#   'argentina': 530,
#   'stronghold': 531,
#   'anarcho-syndicalism': 532,
#   'prominent': 533,
#   'ideology': 534,
#   'time': 535,
#   'minority': 536,
#   'adopt': 537,
#   'violence': 538,
#   'strategy': 539,
#   'propaganda': 540,
#   'deed': 541,
#   'dismemberment': 542,
#   'execution': 543,
#   'exile': 544,
#   'communards': 545,
#   'penal': 546,
#   'colonies': 547,
#   'follow': 548,
#   'suppression': 549,
#   'individualist': 550,
#   'expression': 551,
#   'even': 552,
#   'distance': 553,
#   'terrorist': 554,
#   'infamy': 555,
#   'come': 556,
#   'upon': 557,
#   'make': 558,
#   'exclude': 559,
#   'american': 560,
#   'immigration': 562,
#   '1903': 562,
#   'exclusion': 563,
#   'illegalism': 564,
#   'another': 565,
#   'despite': 566,
#   'enthusiastically': 567,
#   'participate': 568,
#   'white': 569,
#   'however': 570,
#   'harsh': 571,
#   'bolshevik': 572,
#   'government': 573,
#   'stabilise': 574,
#   'petrograd': 575,
#   'moscow': 576,
#   'flee': 577,
#   'ukraine': 578,
#   'kronstadt': 579,
#   'rebellion': 580,
#   'makhnovist': 581,
#   'crush': 582,
#   'russia': 583,
#   'antithetical': 584,
#   'namely': 585,
#   'platformism': 586,
#   'synthesis': 587,
#   'former': 588,
#   'coherent': 589,
#   'push': 590,
#   'anything': 591,
#   'resemble': 592,
#   'see': 593,
#   'victories': 594,
#   'bolsheviks': 595,
#   'october': 596,
#   'result': 597,
#   'activists': 598,
#   'communist': 599,
#   'grow': 600,
#   'expense': 601,
#   'members': 602,
#   'syndicalist': 603,
#   'confederation': 604,
#   'labour': 605,
#   'industrial': 606,
#   'organisations': 607,
#   'join': 608,
#   '1936': 609,
#   'syndicalists': 610,
#   'cnt': 611,
#   'fai': 612,
#   'ally': 613,
#   'leftists': 614,
#   'a': 615,
#   'tradition': 616,
#   'pivotal': 617,
#   'army': 618,
#   'anarchist-inspired': 619,
#   'peasants': 620,
#   'support': 621,
#   'arm': 622,
#   'militias': 623,
#   'control': 624,
#   'barcelona': 625,
#   'large': 626,
#   'rural': 627,
#   'spain': 628,
#   'collectivise': 629,
#   'land': 630,
#   'soviet': 631,
#   'provide': 632,
#   'assistance': 633,
#   'fight': 634,
#   'communists': 635,
#   'series': 636,
#   'events': 637,
#   'name': 638,
#   'may': 639,
#   'days': 640,
#   'joseph': 641,
#   'stalin': 642,
#   'seize': 643,
#   'republicans': 644,
#   'post-war': 645,
#   'ii': 646,
#   'severely': 647,
#   'weaken': 648,
#   '1960s': 649,
#   'witness': 650,
#   'revival': 651,
#   'likely': 652,
#   'cause': 653,
#   'failure': 654,
#   'marxism–leninism': 655,
#   'tensions': 656,
#   'build': 657,
#   'cold': 658,
#   'critical': 659,
#   'towards': 660,
#   'anti-nuclear': 661,
#   'environmental': 662,
#   'peace': 663,
#   'counterculture': 664,
#   'transition': 665,
#   'previous': 666,
#   'provocative': 667,
#   'anti-capitalist': 668,
#   'reformism': 669,
#   'punk': 670,
#   'subculture': 671,
#   'exemplify': 672,
#   'band': 673,
#   'crass': 674,
#   'sex': 675,
#   'pistols': 676,
#   'feminist': 677,
#   'anarcha-feminism': 678,
#   'return': 679,
#   'vigour': 680,
#   'feminism': 681,
#   'black': 682,
#   'move': 683,
#   'eurocentric': 684,
#   'demographic': 685,
#   'coincide': 686,
#   'traction': 687,
#   'northern': 688,
#   'height': 689,
#   'around': 690,
#   'popularity': 691,
#   'anti-war': 692,
#   'anti-globalisation': 693,
#   'involvement': 694,
#   'protest': 695,
#   'trade': 696,
#   'organization': 697,
#   'wto': 698,
#   'eight': 699,
#   'economic': 700,
#   'forum': 701,
#   'ad': 702,
#   'hoc': 703,
#   'leaderless': 704,
#   'anonymous': 705,
#   'cadres': 706,
#   'blocs': 707,
#   'engage': 708,
#   'riot': 709,
#   'destruction': 710,
#   'confrontations': 711,
#   'police': 712,
#   'other': 713,
#   'organisational': 714,
#   'pioneer': 715,
#   'affinity': 716,
#   'security': 717,
#   'culture': 718,
#   'decentralise': 719,
#   'technologies': 720,
#   'internet': 721,
#   'event': 722,
#   '1999': 723,
#   'seattle': 724,
#   'conference': 725,
#   'influential': 726,
#   'zapatistas': 727,
#   'mexico': 728,
#   'democratic': 729,
#   'syria': 737,
#   'commonly': 731,
#   'rojava': 732,
#   'de': 733,
#   'facto': 734,
#   'autonomous': 735,
#   'region': 736,
#   'aspirations': 737,
#   'confrontational': 738,
#   'nowadays': 739,
#   'instead': 740,
#   'alternative': 741,
#   'social': 742,
#   'mutual': 743,
#   'interdependence': 744,
#   'voluntary': 745,
#   'cooperation': 746,
#   'scholar': 747,
#   'carissa': 748,
#   'honeywell': 749,
#   'example': 750,
#   'food': 751,
#   'bomb': 752,
#   'collectives': 753,
#   'work': 757,
#   'direct': 755,
#   'action': 756,
#   'together': 757,
#   'solidarity': 758,
#   'behind': 759,
#   'inform': 760,
#   'rat': 761,
#   'hunger': 766,
#   'suggest': 763,
#   'policies': 772,
#   'tackle': 765,
#   'rag': 766,
#   'de-funding': 767,
#   'industry': 768,
#   'address': 769,
#   'monsanto': 770,
#   'seed-saving': 771,
#   'patent': 772,
#   'help': 773,
#   'farmers': 774,
#   'commodification': 775,
#   'house': 776,
#   'emphasize': 777,
#   'contemporary': 778,
#   'non-humans': 779,
#   'environment': 780,
#   'well': 781,
#   'escalation': 782,
#   'problems': 790,
#   'continous': 784,
#   'poverty': 785,
#   'show': 786,
#   'framework': 787,
#   'solve': 788,
#   'press': 789,
#   'humanity': 790,
#   'causal': 791,
#   'factor': 792,
#   'representative': 793,
#   'democracy': 794,
#   'whole': 795,
#   'main': 796,
#   'historical': 797,
#   'traditions': 798,
#   'owe': 799,
#   'different': 800,
#   'origins': 801,
#   'value': 802,
#   'evolution': 803,
#   'liberty': 807,
#   'restraints': 805,
#   'positive': 806,
#   'achieve': 807,
#   'potential': 808,
#   'equality': 809,
#   'ownership': 810,
#   'chronological': 811,
#   'segment': 812,
#   'post-classical': 813,
#   'green': 814,
#   'post-anarchism': 815,
#   'thereafter': 816,
#   'beyond': 817,
#   'specific': 818,
#   'constitute': 819,
#   'lie': 820,
#   'lack': 821,
#   'moral': 822,
#   'accept': 823,
#   'imperative': 824,
#   'eliminate': 825,
#   'component': 826,
#   'especially': 827,
#   'tolerate': 828,
#   'existence': 829,
#   'minimal': 830,
#   'obligation': 831,
#   'obey': 832,
#   'pay': 833,
#   'attention': 834,
#   'arguments': 835,
#   'ethics': 836,
#   'emphasis': 837,
#   'anti-capitalism': 838,
#   'egalitarianism': 839,
#   'extension': 840,
#   'community': 841,
#   'individuality': 842,
#   'apart': 843,
#   'type': 844,
#   'far-left': 845,
#   'much': 846,
#   'economics': 847,
#   'legal': 848,
#   'reflect': 849,
#   'anti-statist': 850,
#   'radical': 851,
#   'interpretations': 852,
#   'politics': 853,
#   'communism': 854,
#   'theories': 855,
#   'offer': 856,
#   'fix': 857,
#   'doctrine': 858,
#   'single': 859,
#   'worldview': 860,
#   'varieties': 861,
#   'diverge': 862,
#   'widely': 863,
#   'sectarianism': 864,
#   'milieu': 865,
#   'adjectives': 866,
#   'toleration': 867,
#   'unity': 868,
#   'fernando': 869,
#   'tarrida': 870,
#   'del': 871,
#   'mármol': 872,
#   '1889': 873,
#   'debate': 874,
#   'nihilism': 875,
#   'separation': 876,
#   'distinct': 877,
#   'entities': 878,
#   'rather': 879,
#   'intermingle': 880,
#   'connect': 881,
#   'uniform': 882,
#   'local': 883,
#   'aid': 884,
#   'network': 885,
#   'organisation': 886,
#   'communal': 887,
#   'justify': 888,
#   'decentralisation': 889,
#   'inceptive': 890,
#   'they': 891,
#   'differ': 892,
#   'aspects': 893,
#   '18th-century': 894,
#   'its': 895,
#   'reciprocity': 896,
#   'contract': 897,
#   'monetary': 898,
#   'reform': 899,
#   'credit': 900,
#   'currency': 901,
#   'regulate': 902,
#   'bank': 903,
#   'people': 904,
#   'retrospectively': 905,
#   'characterise': 906,
#   'situate': 907,
#   'what': 908,
#   'be': 909,
#   '1840': 910,
#   'goal': 911,
#   'third': 912,
#   'collective': 913,
#   'production': 914,
#   'theorise': 915,
#   'distribute': 916,
#   'arise': 917,
#   'dictatorship': 918,
#   'proletariat': 919,
#   'marxist': 920,
#   'horizontal': 921,
#   'councils': 922,
#   'cooperatives': 923,
#   'consumption': 924,
#   'guide': 925,
#   'principle': 926,
#   'from': 927,
#   'ability': 928,
#   'formulate': 929,
#   'italian': 930,
#   'section': 931,
#   'expand': 932,
#   'theoretical': 933,
#   'style': 934,
#   'go': 935,
#   'onto': 936,
#   'dominate': 937,
#   'branch': 938,
#   'syndicate': 939,
#   'change': 940,
#   'replace': 941,
#   'democratically': 942,
#   'self-managed': 943,
#   'basic': 944,
#   'self-management': 945,
#   'kinds': 946,
#   'external': 947,
#   'determinants': 948,
#   'henry': 949,
#   'david': 950,
#   'thoreau': 951,
#   'through': 952,
#   'attract': 953,
#   'yet': 954,
#   'bohemian': 955,
#   'artists': 956,
#   'intellectuals': 957,
#   'young': 958,
#   'outlaw': 959,
#   'reclamation': 960,
#   'undergird': 961,
#   'momentum': 962,
#   'activist': 963,
#   'orientation': 964,
#   'shape': 965,
#   'radicalism': 966,
#   'embrace': 967,
#   'signal': 968,
#   'continue': 969,
#   'generate': 970,
#   'philosophies': 971,
#   'eclectic': 972,
#   'source': 973,
#   'combine': 974,
#   'concepts': 975,
#   'approach': 976,
#   'remain': 977,
#   'news': 978,
#   'coverage': 979,
#   'bloc': 980,
#   'demonstrations': 981,
#   'reinforce': 982,
#   'chaos': 983,
#   'publicity': 984,
#   'field': 985,
#   'anthropology': 986,
#   'academic': 987,
#   'today': 988,
#   'difficult': 989,
#   'theorists': 990,
#   'relatively': 991,
#   'stable': 992,
#   'constellations': 993,
#   'consensus': 994,
#   'core': 995,
#   'commentators': 996,
#   'multiple': 997,
#   'anarchisms': 998,
#   'singular': 999,
#   ...},
#  'ix_to_word': {0: 'accessiblecomputing',
#   1: 'anarchism',
#   2: 'political',
#   3: 'philosophy',
#   4: 'movement',
#   5: 'skeptical',
#   6: 'justifications',
#   7: 'authority',
#   8: 'seek',
#   9: 'abolish',
#   10: 'institutions',
#   11: 'claim',
#   12: 'maintain',
#   13: 'unnecessary',
#   14: 'coercion',
#   15: 'hierarchy',
#   16: 'typically',
#   17: 'include',
#   18: 'though',
#   19: 'necessarily',
#   20: 'limit',
#   21: 'state',
#   22: 'capitalism',
#   23: 'advocate',
#   24: 'replacement',
#   25: 'stateless',
#   26: 'societies',
#   27: 'form',
#   28: 'free',
#   29: 'associations',
#   30: 'as',
#   31: 'historically',
#   32: 'left-wing',
#   33: 'usually',
#   34: 'place',
#   35: 'farthest',
#   36: 'leave',
#   37: 'spectrum',
#   38: 'usually',
#   39: 'describe',
#   40: 'alongside',
#   41: 'communalism',
#   42: 'libertarian',
#   43: 'marxism',
#   44: 'libertarian',
#   45: 'wing',
#   46: 'libertarian',
#   47: 'socialism',
#   48: 'socialist',
#   49: 'humans',
#   50: 'live',
#   51: 'without',
#   52: 'formal',
#   53: 'hierarchies',
#   54: 'long',
#   55: 'establishment',
#   56: 'formal',
#   57: 'realms',
#   58: 'empires',
#   59: 'with',
#   60: 'rise',
#   61: 'organise',
#   62: 'hierarchical',
#   63: 'body',
#   64: 'scepticism',
#   65: 'toward',
#   66: 'also',
#   67: 'rise',
#   68: 'although',
#   69: 'trace',
#   70: 'anarchist',
#   71: 'think',
#   72: 'find',
#   73: 'throughout',
#   74: 'history',
#   75: 'modern',
#   76: 'emerge',
#   77: 'enlightenment',
#   78: 'during',
#   79: 'latter',
#   80: 'half',
#   81: '19th',
#   82: 'first',
#   83: 'decades',
#   84: '20th',
#   85: 'century',
#   86: 'flourish',
#   87: 'part',
#   88: 'world',
#   89: 'significant',
#   90: 'role',
#   91: 'workers',
#   92: 'struggle',
#   93: 'emancipation',
#   94: 'various',
#   95: 'school',
#   96: 'period',
#   97: 'anarchists',
#   98: 'take',
#   99: 'several',
#   100: 'revolutions',
#   101: 'notably',
#   102: 'paris',
#   103: 'commune',
#   104: 'russian',
#   105: 'civil',
#   106: 'war',
#   107: 'spanish',
#   108: 'civil',
#   109: 'war',
#   110: 'whose',
#   111: 'end',
#   112: 'mark',
#   113: 'end',
#   114: 'classical',
#   115: 'era',
#   116: 'in',
#   117: 'last',
#   118: '21st',
#   119: 'resurgent',
#   120: 'employ',
#   121: 'diversity',
#   122: 'tactics',
#   123: 'order',
#   124: 'meet',
#   125: 'ideal',
#   126: 'broadly',
#   127: 'separate',
#   128: 'revolutionary',
#   129: 'evolutionary',
#   130: 'tactics',
#   131: 'overlap',
#   132: 'two',
#   133: 'merely',
#   134: 'descriptive',
#   135: 'aim',
#   136: 'bring',
#   137: 'violent',
#   138: 'turn',
#   139: 'past',
#   140: 'aim',
#   141: 'prefigure',
#   142: 'society',
#   143: 'would',
#   144: 'like',
#   145: 'criticism',
#   146: 'praxis',
#   147: 'play',
#   148: 'diverse',
#   149: 'areas',
#   150: 'human',
#   151: 'etymology',
#   152: 'terminology',
#   153: 'definition',
#   154: 'the',
#   155: 'etymological',
#   156: 'origin',
#   157: 'ancient',
#   158: 'greek',
#   159: 'anarkhia',
#   160: 'mean',
#   161: 'ruler',
#   162: 'compose',
#   163: 'prefix',
#   164: 'an-',
#   165: 'word',
#   166: 'arkhos',
#   167: 'leader',
#   168: 'ruler',
#   169: 'suffix',
#   170: '-ism',
#   171: 'denote',
#   172: 'ideological',
#   173: 'current',
#   174: 'favour',
#   175: 'anarchy',
#   176: 'appear',
#   177: 'english',
#   178: '1642',
#   179: 'anarchisme',
#   180: '1539',
#   181: 'early',
#   182: 'english',
#   183: 'usages',
#   184: 'emphasise',
#   185: 'sense',
#   186: 'disorder',
#   187: 'factions',
#   188: 'within',
#   189: 'french',
#   190: 'revolution',
#   191: 'label',
#   192: 'opponents',
#   193: 'accuse',
#   194: 'share',
#   195: 'many',
#   196: 'view',
#   197: 'later',
#   198: 'revolutionaries',
#   199: 'william',
#   200: 'godwin',
#   201: '1756–1836',
#   202: 'wilhelm',
#   203: 'weitling',
#   204: '1808–1871',
#   205: 'contribute',
#   206: 'doctrines',
#   207: 'next',
#   208: 'generation',
#   209: 'use',
#   210: 'beliefs',
#   211: 'philosopher',
#   212: 'call',
#   213: 'pierre-joseph',
#   214: 'proudhon',
#   215: '1809–1865',
#   216: 'birth',
#   217: 'mid-19th',
#   218: 'since',
#   219: '1890s',
#   220: 'begin',
#   221: 'france',
#   222: 'libertarianism',
#   223: 'often',
#   224: 'synonym',
#   225: 'synonym',
#   226: 'still',
#   227: 'common',
#   228: 'outside',
#   229: 'unite',
#   230: 'some',
#   231: 'refer',
#   232: 'individualistic',
#   233: 'free-market',
#   234: 'free-market',
#   235: 'particular',
#   236: 'term',
#   237: 'while',
#   238: 'largely',
#   239: 'synonymous',
#   240: 'recently',
#   241: 'dilute',
#   242: 'wider',
#   243: 'adoption',
#   244: 'ideologically',
#   245: 'disparate',
#   246: 'group',
#   247: 'new',
#   248: 'marxists',
#   249: 'associate',
#   250: 'authoritarian',
#   251: 'socialists',
#   252: 'vanguard',
#   253: 'party',
#   254: 'extreme',
#   255: 'cultural',
#   256: 'liberals',
#   257: 'primarily',
#   258: 'concern',
#   259: 'liberties',
#   260: 'additionally',
#   261: 'avoid',
#   262: "'s",
#   263: 'negative',
#   264: 'connotations',
#   265: 'connections',
#   266: 'anti-authoritarian',
#   267: 'contrast',
#   268: 'state-oriented',
#   269: 'scholars',
#   270: 'generally',
#   271: 'highlight',
#   272: 'credentials',
#   273: 'criticise',
#   274: 'attempt',
#   275: 'create',
#   276: 'dichotomies',
#   277: 'influence',
#   278: 'liberalism',
#   279: 'reject',
#   280: 'anarcho-capitalism',
#   281: 'misunderstand',
#   282: 'principles',
#   283: 'opposition',
#   284: 'central',
#   285: 'define',
#   286: 'easy',
#   287: 'task',
#   288: 'lot',
#   289: 'discussion',
#   290: 'among',
#   291: 'matter',
#   292: 'currents',
#   293: 'perceive',
#   294: 'slightly',
#   295: 'differently',
#   296: 'major',
#   297: 'definitional',
#   298: 'elements',
#   299: 'non-coercive',
#   300: 'rejection',
#   301: 'apparatus',
#   302: 'belief',
#   303: 'nature',
#   304: 'allow',
#   305: 'exist',
#   306: 'progress',
#   307: 'non-coercive',
#   308: 'suggestion',
#   309: 'act',
#   310: 'pursue',
#   311: 'pre-modern',
#   312: 'before',
#   313: 'towns',
#   314: 'cities',
#   315: 'establish',
#   316: 'it',
#   317: 'creation',
#   318: 'anarchistic',
#   319: 'ideas',
#   320: 'espouse',
#   321: 'reaction',
#   322: 'notable',
#   323: 'precursors',
#   324: 'china',
#   325: 'greece',
#   326: 'philosophical',
#   327: 'legitimacy',
#   328: 'delineate',
#   329: 'taoist',
#   330: 'philosophers',
#   331: 'zhuang',
#   332: 'zhou',
#   333: 'laozi',
#   334: 'stoicism',
#   335: 'taoism',
#   336: 'say',
#   337: 'anticipations',
#   338: 'anarchic',
#   339: 'attitudes',
#   340: 'articulate',
#   341: 'tragedians',
#   342: 'aeschylus',
#   343: 'sophocles',
#   344: 'myth',
#   345: 'antigone',
#   346: 'illustrate',
#   347: 'conflict',
#   348: 'rule',
#   349: 'set',
#   350: 'personal',
#   351: 'autonomy',
#   352: 'socrates',
#   353: 'question',
#   354: 'athenian',
#   355: 'authorities',
#   356: 'constantly',
#   357: 'insist',
#   358: 'right',
#   359: 'individual',
#   360: 'freedom',
#   361: 'conscience',
#   362: 'cynics',
#   363: 'dismiss',
#   364: 'law',
#   365: 'nomos',
#   366: 'try',
#   367: 'accord',
#   368: 'physis',
#   369: 'stoics',
#   370: 'supportive',
#   371: 'base',
#   372: 'unofficial',
#   373: 'friendly',
#   374: 'relations',
#   375: 'citizens',
#   376: 'presence',
#   377: 'medieval',
#   378: 'europe',
#   379: 'activity',
#   380: 'except',
#   381: 'ascetic',
#   382: 'religious',
#   383: 'movements',
#   384: 'these',
#   385: 'muslim',
#   386: 'give',
#   387: 'sasanian',
#   388: 'empire',
#   389: 'mazdak',
#   390: 'egalitarian',
#   391: 'abolition',
#   392: 'monarchy',
#   393: 'soon',
#   394: 'execute',
#   395: 'emperor',
#   396: 'kavad',
#   397: 'i',
#   398: 'basra',
#   399: 'sects',
#   400: 'preach',
#   401: 'develop',
#   402: 'anti-state',
#   403: 'tendencies',
#   404: 'renew',
#   405: 'interest',
#   406: 'antiquity',
#   407: 'renaissance',
#   408: 'private',
#   409: 'judgment',
#   410: 'reformation',
#   411: 'restore',
#   412: 'secularism',
#   413: 'particularly',
#   414: 'challenge',
#   415: 'intellectual',
#   416: 'secular',
#   417: '1790s',
#   418: '1848',
#   419: 'spur',
#   420: 'development',
#   421: 'become',
#   422: 'partisan',
#   423: 'enragés',
#   424: 'saw',
#   425: 'point',
#   426: 'fermentation',
#   427: 'federalist',
#   428: 'sentiments',
#   429: '18th',
#   430: 'england',
#   431: 'morally',
#   432: 'delegitimising',
#   433: 'max',
#   434: 'stirner',
#   435: 'pave',
#   436: 'way',
#   437: 'individualism',
#   438: 'theory',
#   439: 'mutualism',
#   440: 'fertile',
#   441: 'soil',
#   442: 'by',
#   443: 'late',
#   444: '1870s',
#   445: 'well-defined',
#   446: 'wave',
#   447: 'unprecedented',
#   448: 'globalisation',
#   449: 'occur',
#   450: '1880',
#   451: '1914',
#   452: 'this',
#   453: 'consider',
#   454: 'golden',
#   455: 'age',
#   456: 'draw',
#   457: 'mikhail',
#   458: 'bakunin',
#   459: 'found',
#   460: 'collectivist',
#   461: 'enter',
#   462: 'international',
#   463: 'workingmen',
#   464: 'association',
#   465: 'class',
#   466: 'worker',
#   467: 'union',
#   468: 'know',
#   469: 'international',
#   470: '1864',
#   471: 'force',
#   472: 'karl',
#   473: 'marx',
#   474: 'lead',
#   475: 'figure',
#   476: 'member',
#   477: 'general',
#   478: 'council',
#   479: 'faction',
#   480: 'jura',
#   481: 'federation',
#   482: 'followers',
#   483: 'mutualists',
#   484: 'oppose',
#   485: 'abstentionism',
#   486: 'small',
#   487: 'property',
#   488: 'hold',
#   489: 'after',
#   490: 'bitter',
#   491: 'dispute',
#   492: 'bakuninists',
#   493: 'expel',
#   494: '1872',
#   495: 'hague',
#   496: 'congress',
#   497: 'treat',
#   498: 'similarly',
#   499: 'second',
#   500: 'ultimately',
#   501: '1896',
#   502: 'famously',
#   503: 'predict',
#   504: 'gain',
#   505: 'power',
#   506: 'tyrants',
#   507: 'response',
#   508: 'expulsion',
#   509: 'st.',
#   510: 'imier',
#   511: 'under',
#   512: 'peter',
#   513: 'kropotkin',
#   514: 'scientist',
#   515: 'anarcho-communism',
#   516: 'collectivism',
#   517: 'anarcho-communists',
#   518: 'inspiration',
#   519: '1871',
#   520: 'distribution',
#   521: 'goods',
#   522: 'one',
#   523: 'need',
#   524: 'at',
#   525: 'spread',
#   526: 'feature',
#   527: 'syndicalism',
#   528: 'students',
#   529: 'import',
#   530: 'humanistic',
#   531: 'pro-science',
#   532: 'version',
#   533: 'tokyo',
#   534: 'hotspot',
#   535: 'rebellious',
#   536: 'youth',
#   537: 'countries',
#   538: 'far',
#   539: 'east',
#   540: 'travel',
#   541: 'japanese',
#   542: 'capital',
#   543: 'study',
#   544: 'latin',
#   545: 'america',
#   546: 'argentina',
#   547: 'stronghold',
#   548: 'anarcho-syndicalism',
#   549: 'prominent',
#   550: 'ideology',
#   551: 'time',
#   552: 'minority',
#   553: 'adopt',
#   554: 'violence',
#   555: 'strategy',
#   556: 'propaganda',
#   557: 'deed',
#   558: 'dismemberment',
#   559: 'execution',
#   560: 'exile',
#   561: 'communards',
#   562: 'penal',
#   563: 'colonies',
#   564: 'follow',
#   565: 'suppression',
#   566: 'individualist',
#   567: 'expression',
#   568: 'even',
#   569: 'distance',
#   570: 'terrorist',
#   571: 'infamy',
#   572: 'come',
#   573: 'upon',
#   574: 'make',
#   575: 'exclude',
#   576: 'american',
#   577: 'immigration',
#   578: 'immigration',
#   579: '1903',
#   580: 'exclusion',
#   581: 'illegalism',
#   582: 'another',
#   583: 'despite',
#   584: 'enthusiastically',
#   585: 'participate',
#   586: 'white',
#   587: 'however',
#   588: 'harsh',
#   589: 'bolshevik',
#   590: 'government',
#   591: 'stabilise',
#   592: 'petrograd',
#   593: 'moscow',
#   594: 'flee',
#   595: 'ukraine',
#   596: 'kronstadt',
#   597: 'rebellion',
#   598: 'makhnovist',
#   599: 'crush',
#   600: 'russia',
#   601: 'antithetical',
#   602: 'namely',
#   603: 'platformism',
#   604: 'synthesis',
#   605: 'former',
#   606: 'coherent',
#   607: 'push',
#   608: 'anything',
#   609: 'resemble',
#   610: 'see',
#   611: 'victories',
#   612: 'bolsheviks',
#   613: 'october',
#   614: 'result',
#   615: 'activists',
#   616: 'communist',
#   617: 'grow',
#   618: 'expense',
#   619: 'members',
#   620: 'syndicalist',
#   621: 'confederation',
#   622: 'labour',
#   623: 'industrial',
#   624: 'organisations',
#   625: 'join',
#   626: '1936',
#   627: 'syndicalists',
#   628: 'cnt',
#   629: 'fai',
#   630: 'ally',
#   631: 'leftists',
#   632: 'a',
#   633: 'tradition',
#   634: 'pivotal',
#   635: 'army',
#   636: 'anarchist-inspired',
#   637: 'peasants',
#   638: 'support',
#   639: 'arm',
#   640: 'militias',
#   641: 'control',
#   642: 'barcelona',
#   643: 'large',
#   644: 'rural',
#   645: 'spain',
#   646: 'collectivise',
#   647: 'land',
#   648: 'soviet',
#   649: 'provide',
#   650: 'assistance',
#   651: 'fight',
#   652: 'communists',
#   653: 'series',
#   654: 'events',
#   655: 'name',
#   656: 'may',
#   657: 'days',
#   658: 'joseph',
#   659: 'stalin',
#   660: 'seize',
#   661: 'republicans',
#   662: 'post-war',
#   663: 'ii',
#   664: 'severely',
#   665: 'weaken',
#   666: '1960s',
#   667: 'witness',
#   668: 'revival',
#   669: 'likely',
#   670: 'cause',
#   671: 'failure',
#   672: 'marxism–leninism',
#   673: 'tensions',
#   674: 'build',
#   675: 'cold',
#   676: 'critical',
#   677: 'towards',
#   678: 'anti-nuclear',
#   679: 'environmental',
#   680: 'peace',
#   681: 'counterculture',
#   682: 'transition',
#   683: 'previous',
#   684: 'provocative',
#   685: 'anti-capitalist',
#   686: 'reformism',
#   687: 'punk',
#   688: 'subculture',
#   689: 'exemplify',
#   690: 'band',
#   691: 'crass',
#   692: 'sex',
#   693: 'pistols',
#   694: 'feminist',
#   695: 'anarcha-feminism',
#   696: 'return',
#   697: 'vigour',
#   698: 'feminism',
#   699: 'black',
#   700: 'move',
#   701: 'eurocentric',
#   702: 'demographic',
#   703: 'coincide',
#   704: 'traction',
#   705: 'northern',
#   706: 'height',
#   707: 'around',
#   708: 'popularity',
#   709: 'anti-war',
#   710: 'anti-globalisation',
#   711: 'involvement',
#   712: 'protest',
#   713: 'trade',
#   714: 'organization',
#   715: 'wto',
#   716: 'eight',
#   717: 'economic',
#   718: 'forum',
#   719: 'ad',
#   720: 'hoc',
#   721: 'leaderless',
#   722: 'anonymous',
#   723: 'cadres',
#   724: 'blocs',
#   725: 'engage',
#   726: 'riot',
#   727: 'destruction',
#   728: 'confrontations',
#   729: 'police',
#   730: 'other',
#   731: 'organisational',
#   732: 'pioneer',
#   733: 'affinity',
#   734: 'security',
#   735: 'culture',
#   736: 'decentralise',
#   737: 'technologies',
#   738: 'internet',
#   739: 'event',
#   740: '1999',
#   741: 'seattle',
#   742: 'conference',
#   743: 'influential',
#   744: 'zapatistas',
#   745: 'mexico',
#   746: 'democratic',
#   747: 'syria',
#   748: 'commonly',
#   749: 'rojava',
#   750: 'de',
#   751: 'facto',
#   752: 'autonomous',
#   753: 'region',
#   754: 'syria',
#   755: 'aspirations',
#   756: 'confrontational',
#   757: 'nowadays',
#   758: 'instead',
#   759: 'alternative',
#   760: 'social',
#   761: 'mutual',
#   762: 'interdependence',
#   763: 'voluntary',
#   764: 'cooperation',
#   765: 'scholar',
#   766: 'carissa',
#   767: 'honeywell',
#   768: 'example',
#   769: 'food',
#   770: 'bomb',
#   771: 'collectives',
#   772: 'work',
#   773: 'direct',
#   774: 'action',
#   775: 'work',
#   776: 'together',
#   777: 'solidarity',
#   778: 'behind',
#   779: 'inform',
#   780: 'rat',
#   781: 'hunger',
#   782: 'suggest',
#   783: 'policies',
#   784: 'tackle',
#   785: 'hunger',
#   786: 'rag',
#   787: 'de-funding',
#   788: 'industry',
#   789: 'address',
#   790: 'monsanto',
#   791: 'seed-saving',
#   792: 'policies',
#   793: 'patent',
#   794: 'help',
#   795: 'farmers',
#   796: 'commodification',
#   797: 'house',
#   798: 'emphasize',
#   799: 'contemporary',
#   800: 'non-humans',
#   801: 'environment',
#   802: 'well',
#   803: 'escalation',
#   804: 'problems',
#   805: 'continous',
#   806: 'poverty',
#   807: 'show',
#   808: 'framework',
#   809: 'solve',
#   810: 'press',
#   811: 'problems',
#   812: 'humanity',
#   813: 'causal',
#   814: 'factor',
#   815: 'representative',
#   816: 'democracy',
#   817: 'whole',
#   818: 'main',
#   819: 'historical',
#   820: 'traditions',
#   821: 'owe',
#   822: 'different',
#   823: 'origins',
#   824: 'value',
#   825: 'evolution',
#   826: 'liberty',
#   827: 'restraints',
#   828: 'positive',
#   829: 'liberty',
#   830: 'achieve',
#   831: 'potential',
#   832: 'equality',
#   833: 'ownership',
#   834: 'chronological',
#   835: 'segment',
#   836: 'post-classical',
#   837: 'green',
#   838: 'post-anarchism',
#   839: 'thereafter',
#   840: 'beyond',
#   841: 'specific',
#   842: 'constitute',
#   843: 'lie',
#   844: 'lack',
#   845: 'moral',
#   846: 'accept',
#   847: 'imperative',
#   848: 'eliminate',
#   849: 'component',
#   850: 'especially',
#   851: 'tolerate',
#   852: 'existence',
#   853: 'minimal',
#   854: 'obligation',
#   855: 'obey',
#   856: 'pay',
#   857: 'attention',
#   858: 'arguments',
#   859: 'ethics',
#   860: 'emphasis',
#   861: 'anti-capitalism',
#   862: 'egalitarianism',
#   863: 'extension',
#   864: 'community',
#   865: 'individuality',
#   866: 'apart',
#   867: 'type',
#   868: 'far-left',
#   869: 'much',
#   870: 'economics',
#   871: 'legal',
#   872: 'reflect',
#   873: 'anti-statist',
#   874: 'radical',
#   875: 'interpretations',
#   876: 'politics',
#   877: 'communism',
#   878: 'theories',
#   879: 'offer',
#   880: 'fix',
#   881: 'doctrine',
#   882: 'single',
#   883: 'worldview',
#   884: 'varieties',
#   885: 'diverge',
#   886: 'widely',
#   887: 'sectarianism',
#   888: 'milieu',
#   889: 'adjectives',
#   890: 'toleration',
#   891: 'unity',
#   892: 'fernando',
#   893: 'tarrida',
#   894: 'del',
#   895: 'mármol',
#   896: '1889',
#   897: 'debate',
#   898: 'nihilism',
#   899: 'separation',
#   900: 'distinct',
#   901: 'entities',
#   902: 'rather',
#   903: 'intermingle',
#   904: 'connect',
#   905: 'uniform',
#   906: 'local',
#   907: 'aid',
#   908: 'network',
#   909: 'organisation',
#   910: 'communal',
#   911: 'justify',
#   912: 'decentralisation',
#   913: 'inceptive',
#   914: 'they',
#   915: 'differ',
#   916: 'aspects',
#   917: '18th-century',
#   918: 'its',
#   919: 'reciprocity',
#   920: 'contract',
#   921: 'monetary',
#   922: 'reform',
#   923: 'credit',
#   924: 'currency',
#   925: 'regulate',
#   926: 'bank',
#   927: 'people',
#   928: 'retrospectively',
#   929: 'characterise',
#   930: 'situate',
#   931: 'what',
#   932: 'be',
#   933: '1840',
#   934: 'goal',
#   935: 'third',
#   936: 'collective',
#   937: 'production',
#   938: 'theorise',
#   939: 'distribute',
#   940: 'arise',
#   941: 'dictatorship',
#   942: 'proletariat',
#   943: 'marxist',
#   944: 'horizontal',
#   945: 'councils',
#   946: 'cooperatives',
#   947: 'consumption',
#   948: 'guide',
#   949: 'principle',
#   950: 'from',
#   951: 'ability',
#   952: 'formulate',
#   953: 'italian',
#   954: 'section',
#   955: 'expand',
#   956: 'theoretical',
#   957: 'style',
#   958: 'go',
#   959: 'onto',
#   960: 'dominate',
#   961: 'branch',
#   962: 'syndicate',
#   963: 'change',
#   964: 'replace',
#   965: 'democratically',
#   966: 'self-managed',
#   967: 'basic',
#   968: 'self-management',
#   969: 'kinds',
#   970: 'external',
#   971: 'determinants',
#   972: 'henry',
#   973: 'david',
#   974: 'thoreau',
#   975: 'through',
#   976: 'attract',
#   977: 'yet',
#   978: 'bohemian',
#   979: 'artists',
#   980: 'intellectuals',
#   981: 'young',
#   982: 'outlaw',
#   983: 'reclamation',
#   984: 'undergird',
#   985: 'momentum',
#   986: 'activist',
#   987: 'orientation',
#   988: 'shape',
#   989: 'radicalism',
#   990: 'embrace',
#   991: 'signal',
#   992: 'continue',
#   993: 'generate',
#   994: 'philosophies',
#   995: 'eclectic',
#   996: 'source',
#   997: 'combine',
#   998: 'concepts',
#   999: 'approach',
#   ...}}

# %% [markdown]
# ---

# %% [markdown]
# # Testing the Model

# %%
import pandas as pd

# %%
TEST_DIR = "data/SimLex-999"

# %%
test_dataset = pd.read_csv(f"{TEST_DIR}/SimLex-999.txt", sep ="\t")

# %%
test_dataset
# Out:
#       word1        word2 POS  SimLex999  conc(w1)  conc(w2)  concQ  \
# 0       old          new   A       1.58      2.72      2.81      2
# 1     smart  intelligent   A       9.20      1.75      2.46      1
# 2      hard    difficult   A       8.77      3.76      2.21      2
# 3     happy     cheerful   A       9.55      2.56      2.34      1
# 4      hard         easy   A       0.95      3.76      2.07      2
# ..      ...          ...  ..        ...       ...       ...    ...
# 994    join      acquire   V       2.85      2.86      2.93      2
# 995    send       attend   V       1.67      2.70      3.17      2
# 996  gather       attend   V       4.80      2.75      3.17      2
# 997  absorb     withdraw   V       2.97      3.11      3.04      2
# 998  attend       arrive   V       6.08      3.17      3.22      2
#
#      Assoc(USF)  SimAssoc333  SD(SimLex)
# 0          7.25            1        0.41
# 1          7.11            1        0.67
# 2          5.94            1        1.19
# 3          5.85            1        2.18
# 4          5.82            1        0.93
# ..          ...          ...         ...
# 994        0.00            0        0.99
# 995        0.00            0        1.44
# 996        0.00            0        1.97
# 997        0.00            0        1.75
# 998        0.00            0        1.18
#
# [999 rows x 10 columns]
